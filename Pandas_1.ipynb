# %% [markdown]
# ## Phân tích và xử lí dữ liệu với pandas

# %% [markdown]
# # 1) Giới thiệu
# ---
# **Pandas** là một thư viện mã nguồn mở được xây dựng dựa trên NumPy, sử dụng để thao tác và phân tích dữ liệu. Với Pandas chúng ta có thể:
# Xử lý tập dữ liệu khác nhau về định dạng: chuỗi thời gian, bảng không đồng nhất, ma trận dữ liệu
# * Import dữ liệu từ nhiều nguồn khác nhau như CSV, DB/SQL…
# * Xử lý vô số phép toán cho tập dữ liệu: subsetting, slicing, filtering, merging, groupBy, re-ordering, and re-shaping,..
# * Xử lý dữ liệu mất mát theo mong muốn.
# * Xử lý, phân tích dữ liệu tốt như mô hình hoá và thống kê.
# * Tích hợp tốt với các thư viện khác của python.
#
# https://pandas.pydata.org/

# %%
#Kiểm tra phiên bản của thư viện Pandas
import pandas as pd
print('pandas libary',pd.__version__)

# %% [markdown]
# # 2) Làm việc với các đối tượng trong Pandas
# ---
# ## 2.1) Series

# %%
#Khai báo sử dụng thư viện (pandas, numpy, matplotlib.pyplot)
import pandas as pd
import numpy as np
import matplotlib.pyplot as mat

# %%
#Tạo một đối tượng series
#index mặc định đánh số từ 0
data = pd.Series([2.8, 3, 4.44, 5])
data
# Out:
# 0    2.80
# 1    3.00
# 2    4.44
# 3    5.00
# dtype: float64

# %%
#Mỗi một đối tượng series bao gồm 2 thành phần
#1. Values
#2. index
print('Values:', data.values)
print('Indices:', data.index)
# Out:
# Values: [2.8  3.   4.44 5.  ]
# Indices: RangeIndex(start=0, stop=4, step=1)

# %%
#Tạo một đối tượng series với index thiết lập
data = pd.Series([1.25, 2, 3.5, 4.75, 8.0],
                 index=['a', 'b', 'c', 'd','k'])
data
# Out:
# a    1.25
# b    2.00
# c    3.50
# d    4.75
# k    8.00
# dtype: float64

# %%
print('Values:', data.values)
print('Indices:', data.index)
# Out:
# Values: [1.25 2.   3.5  4.75 8.  ]
# Indices: Index(['a', 'b', 'c', 'd', 'k'], dtype='object')

# %%
#Truy cập tới một phần tử trong series thông qua index hoặc thứ tự
print('Phần tử có index = b:', data['b'])
print('Phần tử ở vị trí 1  :', data[1])
# Out:
# Phần tử có index = b: 2.0
# Phần tử ở vị trí 1  : 2.0

# %%
#Tạo đối tượng series từ một biến kiểu Dictionary
#Chỉ số được tự động sắp xếp.
population_dict = {'California': 38332521,
                   'Texas': 26448193,
                   'New York': 19651127,
                   'Florida': 19552860,
                   'Illinois': 12882135}
population = pd.Series(population_dict,name='Population_USA')
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# Name: Population_USA, dtype: int64

# %%
#View tên của series
population.Population_USA
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-3139193adfd8> in <module>
#       1 #View tên của series
# ----> 2 population.Population_USA
#
# NameError: name 'population' is not defined

# %%
population['Florida']
# Out:
# 19552860

# %%
#Chuyển đổi từ dữ liệu vector sang series
a_vector = np.array([8,12,9,0,7,11])

a_series = pd.Series(a_vector,dtype='float')
a_series
# Out:
# 0     8.0
# 1    12.0
# 2     9.0
# 3     0.0
# 4     7.0
# 5    11.0
# dtype: float64

# %% [markdown]
# ## 1.2) DataFrame
# ---

# %%
#Tạo DataFrame từ các Series
area_dict = {'California': 423967, 
             'Texas': 695662, 
             'New York': 141297,
             'Florida': 170312, 
             'Illinois': 149995}
area = pd.Series(area_dict, name='Area_USA')
area

# %%
data_usa = pd.DataFrame({'population':population,
                         'area':area})
data_usa

# %%
#Tương tự như series, DataFrame cũng có thuộc tính values và index
df_values = data_usa.values
df_index = data_usa.index
print('Values of DataFrame:\n',df_values)
print('Index of DataFrame:\n',df_index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-a62437ba54e3> in <module>
#       1 #Tương tự như series, DataFrame cũng có thuộc tính values và index
# ----> 2 df_values = data_usa.values
#       3 df_index = data_usa.index
#       4 print('Values of DataFrame:\n',df_values)
#       5 print('Index of DataFrame:\n',df_index)
#
# NameError: name 'data_usa' is not defined

# %%
#Tạo một DataFrame từ một biến Dict
#Chỉ số được tạo mặc định từ 0
data_dict = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]}

purchases = pd.DataFrame(data_dict)
purchases

# %%
#Tạo DataFrame với index thiết lập
purchases = pd.DataFrame(data_dict, 
                         index=['June', 'Robert', 'Lily', 'David'])
purchases

# %% [markdown]
# # 3) Đọc dữ liệu từ các nguồn khác nhau (CSV, Excel)
# ---
# ## 3.1) Đọc file CSV

# %%
import pandas as pd
path = 'D:/hoctap/datatrainningpython/csv_Data_Loan.csv'
#Sử dụng phương thức read_csv
data = pd.read_csv(path)
#Hiển thị thông tin biến Data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163987 entries, 0 to 163986
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   loan_amnt              163987 non-null  int64
#  1   term                   163987 non-null  object
#  2   int_rate               163987 non-null  float64
#  3   emp_length             158183 non-null  float64
#  4   home_ownership         163987 non-null  object
#  5   annual_inc             163983 non-null  float64
#  6   purpose                163987 non-null  object
#  7   addr_state             163987 non-null  object
#  8   dti                    163987 non-null  float64
#  9   delinq_2yrs            163958 non-null  float64
#  10  revol_util             163794 non-null  float64
#  11  total_acc              163958 non-null  float64
#  12  bad_loan               163987 non-null  int64
#  13  longest_credit_length  163958 non-null  float64
#  14  verification_status    163987 non-null  object
# dtypes: float64(8), int64(2), object(5)
# memory usage: 18.8+ MB

# %%
#VÍ DỤ 1:
#Sử dụng phương thức read_csv()
#Tham số: Thiết lập cột index là cột Personal
data1 = pd.read_csv(path,
                    index_col=0)
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163987 entries, 5000 to 17000
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   term                   163987 non-null  object
#  1   int_rate               163987 non-null  float64
#  2   emp_length             158183 non-null  float64
#  3   home_ownership         163987 non-null  object
#  4   annual_inc             163983 non-null  float64
#  5   purpose                163987 non-null  object
#  6   addr_state             163987 non-null  object
#  7   dti                    163987 non-null  float64
#  8   delinq_2yrs            163958 non-null  float64
#  9   revol_util             163794 non-null  float64
#  10  total_acc              163958 non-null  float64
#  11  bad_loan               163987 non-null  int64
#  12  longest_credit_length  163958 non-null  float64
#  13  verification_status    163987 non-null  object
# dtypes: float64(8), int64(1), object(5)
# memory usage: 18.8+ MB

# %%
#VÍ DỤ 2:
#Sử dụng phương thức read_csv()
#Thiết lập số hàng, cột muốn đọc dữ liệu
data2 = pd.read_csv(path,
                    nrows=100,
                    usecols=['Height_cm', 'Weight_kg'])
data2.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-f1ac5029a932> in <module>
#       2 #Sử dụng phương thức read_csv()
#       3 #Thiết lập số hàng, cột muốn đọc dữ liệu
# ----> 4 data2 = pd.read_csv(path,
#       5                     nrows=100,
#       6                     usecols=['Height_cm', 'Weight_kg'])
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1947                 self.orig_names
#    1948             ):
# -> 1949                 _validate_usecols_names(usecols, self.orig_names)
#    1950
#    1951             if len(self.names) > len(usecols):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _validate_usecols_names(usecols, names)
#    1160     missing = [c for c in usecols if c not in names]
#    1161     if len(missing) > 0:
# -> 1162         raise ValueError(
#    1163             f"Usecols do not match columns, columns expected but not found: {missing}"
#    1164         )
#
# ValueError: Usecols do not match columns, columns expected but not found: ['Height_cm', 'Weight_kg']

# %%
#VÍ DỤ 3:
#Thiết lập tham số đọc dữ liệu từ dòng thứ 5 trong file
#và đặt lại tên của các cột dữ liệu
data3 = pd.read_csv(path,
                    names=['ID','Sex','H(cm)','W(kg)'],
                    skiprows=5)
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 163983 entries, (5000, '36 months', 7.9, 3.0, 'RENT', 36000.0, 'wedding', 'AZ', 11.2, 0.0, 28.3) to (17000, '60 months', 15.99, 10.0, 'MORTGAGE', 63078.0, 'debt_consolidation', 'PA', 31.7, 0.0, 54.0)
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      163954 non-null  float64
#  1   Sex     163983 non-null  int64
#  2   H(cm)   163954 non-null  float64
#  3   W(kg)   163983 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 8.4+ MB

# %% [markdown]
# ## THỰC HÀNH 3.1
# ---
# **Yêu cầu 1: Đọc dữ liệu dạng CSV lưu trong file Data_Loan.csv với các tham số mặc định**

# %%
#{VIẾT CODE Ở ĐÂY}
import pandas as pd
path_csv='D:/hoctap/datatrainningpython/csv_Data_Loan.csv'

pd_data = pd.read_csv(path_csv)
pd_data.info()
#pd_data.head()
#pd_data.describe()
#pd_data["emp_length"].plot
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163987 entries, 0 to 163986
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   loan_amnt              163987 non-null  int64
#  1   term                   163987 non-null  object
#  2   int_rate               163987 non-null  float64
#  3   emp_length             158183 non-null  float64
#  4   home_ownership         163987 non-null  object
#  5   annual_inc             163983 non-null  float64
#  6   purpose                163987 non-null  object
#  7   addr_state             163987 non-null  object
#  8   dti                    163987 non-null  float64
#  9   delinq_2yrs            163958 non-null  float64
#  10  revol_util             163794 non-null  float64
#  11  total_acc              163958 non-null  float64
#  12  bad_loan               163987 non-null  int64
#  13  longest_credit_length  163958 non-null  float64
#  14  verification_status    163987 non-null  object
# dtypes: float64(8), int64(2), object(5)
# memory usage: 18.8+ MB

# %% [markdown]
# **Yêu cầu 2: Đọc dữ liệu từ file Data_Loan.CSV vào 2 biến DataFrame tương ứng**
# 1. df_number: Chỉ chứa các cột dữ liệu số
# 2. df_object: Chỉ chứa các cột dữ liệu Object

# %%
#{VIẾT CODE Ở ĐÂY}
df_number=pd_data.select_dtypes(include=["int64","float64"])
df_number.head()
# Out:
#    loan_amnt  int_rate  emp_length  annual_inc    dti  delinq_2yrs  \
# 0       5000     10.65        10.0     24000.0  27.65          0.0
# 1       2500     15.27         0.0     30000.0   1.00          0.0
# 2       2400     15.96        10.0     12252.0   8.72          0.0
# 3      10000     13.49        10.0     49200.0  20.00          0.0
# 4       5000      7.90         3.0     36000.0  11.20          0.0
#
#    revol_util  total_acc  bad_loan  longest_credit_length
# 0        83.7        9.0         0                   26.0
# 1         9.4        4.0         1                   12.0
# 2        98.5       10.0         0                   10.0
# 3        21.0       37.0         0                   15.0
# 4        28.3       12.0         0                    7.0

# %%
df_object=pd_data.select_dtypes(include=["object"])
df_object.head()
# Out:
#         term home_ownership         purpose addr_state verification_status
# 0  36 months           RENT     credit_card         AZ            verified
# 1  60 months           RENT             car         GA            verified
# 2  36 months           RENT  small_business         IL        not verified
# 3  36 months           RENT           other         CA            verified
# 4  36 months           RENT         wedding         AZ            verified

# %% [markdown]
# ## Đọc file Excel
# ---

# %%
import pandas as pd
path_excel = 'D:/hoctap/datatrainningpython/excel_Data_Point.xlsx'
#Đọc dữ liệu từ file excel
data_ex = pd.read_excel(path_excel)
data_ex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STT        66 non-null     int64
#  1   Mã SV      66 non-null     int64
#  2   Họ         66 non-null     object
#  3   Tên        66 non-null     object
#  4   Ngày sinh  66 non-null     object
#  5   Tên Lớp    66 non-null     object
#  6   A          66 non-null     float64
#  7   B1         66 non-null     float64
#  8   B2         66 non-null     float64
#  9   C1         66 non-null     float64
#  10  C2         66 non-null     float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 5.8+ KB

# %%
#VÍ DỤ 1:
#Đọc dữ liệu tại sheet đầu tiên, 
#Chỉ lấy dữ liệu cột Mã SV và các cột điểm 
#Thiết lập cột đầu tiên làm index
data_ex1 = pd.read_excel(path_excel,
                        sheet_name='4080130_01',
                        usecols=[1,6,7,8,9,10],
                        index_col=0)
data_ex1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66 entries, 1621050322 to 1621050013
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       66 non-null     float64
#  1   B1      66 non-null     float64
#  2   B2      66 non-null     float64
#  3   C1      66 non-null     float64
#  4   C2      66 non-null     float64
# dtypes: float64(5)
# memory usage: 3.1 KB

# %%
#VÍ DỤ 2:
#Đọc dữ liệu tại sheet 2, 
#Trường hợp: sử dụng các tham số mặc định
data_ex2 = pd.read_excel(path_excel,
                        sheet_name=1)
data_ex2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 11 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Cộng Hòa Xã Hội Chủ Nghĩa Việt Nam  45 non-null     object
#  1   Unnamed: 1                          40 non-null     object
#  2   Unnamed: 2                          40 non-null     object
#  3   Unnamed: 3                          40 non-null     object
#  4   Unnamed: 4                          42 non-null     object
#  5   Unnamed: 5                          40 non-null     object
#  6   Unnamed: 6                          40 non-null     object
#  7   Unnamed: 7                          40 non-null     object
#  8   Unnamed: 8                          40 non-null     object
#  9   Unnamed: 9                          40 non-null     object
#  10  Unnamed: 10                         40 non-null     object
# dtypes: object(11)
# memory usage: 4.2+ KB

# %%
#VÍ DỤ 3:
#Đọc dữ liệu tại sheet '4080130_02',từ dòng 9
data_ex3 = pd.read_excel(path_excel,
                         sheet_name='4080130_02',
                         skiprows=9)
data_ex3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STT        39 non-null     int64
#  1   Mã SV      39 non-null     int64
#  2   Họ         39 non-null     object
#  3   Tên        39 non-null     object
#  4   Ngày sinh  39 non-null     object
#  5   Tên Lớp    39 non-null     object
#  6   A          39 non-null     float64
#  7   B1         39 non-null     float64
#  8   B2         39 non-null     float64
#  9   C1         39 non-null     float64
#  10  C2         39 non-null     float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 3.5+ KB

# %%
#VÍ DỤ 4
#Đọc dữ liệu từ sheet: '4080130_03'
#Dữ liệu không chứa dòng header
data_ex4 = pd.read_excel(path_excel,
                        sheet_name='4080130_03',
                        header=None)
data_ex4.head()
# Out:
#    0           1           2      3           4           5    6    7    8   \
# 0   1  1621050041    Đào Tuấn    Anh  22/10/1998  DCCTPM61_1  6.7  9.0  5.5
# 1   2  1621050262  Vũ Thị Lan    Anh  26/09/1998  DCCTPM61_1  6.7  7.0  9.0
# 2   3  1621050083   Trịnh Như   Bình  06/04/1998  DCCTPM61_1  7.3  8.5  9.5
# 3   4  1621050113    Trần Văn  Cương  19/06/1998  DCCTPM61_1  5.7  5.0  6.0
# 4   5  1621050384   Nguyễn Sỹ   Dũng  02/10/1998  DCCTPM61_1  7.0  0.0  7.5
#
#      9    10
# 0   8.5  8.0
# 1   8.5  6.0
# 2  10.0  9.0
# 3  10.0  5.0
# 4   8.5  9.0

# %%
#Ví dụ 4.1
#Đọc dữ liệu từ sheet: '4080130_03'
#Dữ liệu không chứa dòng header
#Đặt tên cho các cột
data_ex41 = pd.read_excel(path_excel,
                        sheet_name='4080130_03',
                        header=None,
                        usecols=[1,6,7,8,9,10],
                        names=['Mã SV','A','B1','B2','C1','C2'],
                        index_col=0)
data_ex41.head()
# Out:
#               A   B1   B2    C1   C2
# Mã SV
# 1621050041  6.7  9.0  5.5   8.5  8.0
# 1621050262  6.7  7.0  9.0   8.5  6.0
# 1621050083  7.3  8.5  9.5  10.0  9.0
# 1621050113  5.7  5.0  6.0  10.0  5.0
# 1621050384  7.0  0.0  7.5   8.5  9.0

# %% [markdown]
# ## THỰC HÀNH 3.2
# ---
# Yêu cầu: Đọc dữ liệu dạng excel lưu trong file excel_Data_Movies.xls theo từng sheet

# %%
#{VIẾT CODE Ở ĐÂY}
import pandas as pd
path_excel='D:/hoctap/datatrainningpython/excel_Data_Movies.xls'
data_ex4 = pd.read_excel(path_excel,
                        sheet_name=0)
data_ex4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Title                        1338 non-null   object
#  1   Year                         1338 non-null   int64
#  2   Genres                       1338 non-null   object
#  3   Language                     1334 non-null   object
#  4   Country                      1338 non-null   object
#  5   Content Rating               1316 non-null   object
#  6   Duration                     1338 non-null   int64
#  7   Aspect Ratio                 1308 non-null   float64
#  8   Budget                       1281 non-null   float64
#  9   Gross Earnings               1086 non-null   float64
#  10  Director                     1338 non-null   object
#  11  Actor 1                      1338 non-null   object
#  12  Actor 2                      1338 non-null   object
#  13  Actor 3                      1336 non-null   object
#  14  Facebook Likes - Director    1338 non-null   int64
#  15  Facebook Likes - Actor 1     1338 non-null   int64
#  16  Facebook Likes - Actor 2     1338 non-null   int64
#  17  Facebook Likes - Actor 3     1336 non-null   float64
#  18  Facebook Likes - cast Total  1338 non-null   int64
#  19  Facebook likes - Movie       1338 non-null   int64
#  20  Facenumber in posters        1338 non-null   int64
#  21  User Votes                   1338 non-null   int64
#  22  Reviews by Users             1338 non-null   int64
#  23  Reviews by Crtiics           1335 non-null   float64
#  24  IMDB Score                   1338 non-null   float64
# dtypes: float64(6), int64(10), object(9)
# memory usage: 261.5+ KB

# %% [markdown]
# # 3) Quan sát và truy suất dữ liệu từ DataFrame
# ---
# ## 3.1) Quan sát dữ liệu

# %%
#Đọc dữ liệu mẫu được lưu trữ trong file csv
path='D:/hoctap/datatrainningpython/csv_Data_Loan.csv'
df_loan=pd.read_csv(path)
df_loan
# Out:
#         loan_amnt       term  int_rate  emp_length home_ownership  annual_inc  \
# 0            5000  36 months     10.65        10.0           RENT     24000.0
# 1            2500  60 months     15.27         0.0           RENT     30000.0
# 2            2400  36 months     15.96        10.0           RENT     12252.0
# 3           10000  36 months     13.49        10.0           RENT     49200.0
# 4            5000  36 months      7.90         3.0           RENT     36000.0
# ...           ...        ...       ...         ...            ...         ...
# 163982      15000  60 months     12.39         3.0       MORTGAGE     45000.0
# 163983      20000  36 months     14.99        10.0            OWN     80000.0
# 163984      12825  36 months     17.14         6.0       MORTGAGE     38000.0
# 163985      27650  60 months     21.99         0.0           RENT     60000.0
# 163986      17000  60 months     15.99        10.0       MORTGAGE     63078.0
#
#                    purpose addr_state    dti  delinq_2yrs  revol_util  \
# 0              credit_card         AZ  27.65          0.0        83.7
# 1                      car         GA   1.00          0.0         9.4
# 2           small_business         IL   8.72          0.0        98.5
# 3                    other         CA  20.00          0.0        21.0
# 4                  wedding         AZ  11.20          0.0        28.3
# ...                    ...        ...    ...          ...         ...
# 163982         credit_card         OK  31.44          4.0        75.8
# 163983    home_improvement         VA  23.65          0.0        68.8
# 163984  debt_consolidation         TX   9.03          0.0        70.7
# 163985         credit_card         NY  10.10          1.0        61.2
# 163986  debt_consolidation         PA  31.70          0.0        54.0
#
#         total_acc  bad_loan  longest_credit_length verification_status
# 0             9.0         0                   26.0            verified
# 1             4.0         1                   12.0            verified
# 2            10.0         0                   10.0        not verified
# 3            37.0         0                   15.0            verified
# 4            12.0         0                    7.0            verified
# ...           ...       ...                    ...                 ...
# 163982       34.0         0                   20.0        not verified
# 163983       18.0         0                   22.0            verified
# 163984       24.0         0                    9.0        not verified
# 163985       20.0         0                    6.0            verified
# 163986       28.0         0                   16.0            verified
#
# [163987 rows x 15 columns]

# %%
#Quan sát dữ liệu biến DataFrame
df_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163987 entries, 0 to 163986
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   loan_amnt              163987 non-null  int64
#  1   term                   163987 non-null  object
#  2   int_rate               163987 non-null  float64
#  3   emp_length             158183 non-null  float64
#  4   home_ownership         163987 non-null  object
#  5   annual_inc             163983 non-null  float64
#  6   purpose                163987 non-null  object
#  7   addr_state             163987 non-null  object
#  8   dti                    163987 non-null  float64
#  9   delinq_2yrs            163958 non-null  float64
#  10  revol_util             163794 non-null  float64
#  11  total_acc              163958 non-null  float64
#  12  bad_loan               163987 non-null  int64
#  13  longest_credit_length  163958 non-null  float64
#  14  verification_status    163987 non-null  object
# dtypes: float64(8), int64(2), object(5)
# memory usage: 18.8+ MB

# %%
#Hiển thị 10 dòng đầu tiên
df_loan.head(12)
# Out:
#     loan_amnt       term  int_rate  emp_length home_ownership  annual_inc  \
# 0        5000  36 months     10.65        10.0           RENT     24000.0
# 1        2500  60 months     15.27         0.0           RENT     30000.0
# 2        2400  36 months     15.96        10.0           RENT     12252.0
# 3       10000  36 months     13.49        10.0           RENT     49200.0
# 4        5000  36 months      7.90         3.0           RENT     36000.0
# 5        3000  36 months     18.64         9.0           RENT     48000.0
# 6        5600  60 months     21.28         4.0            OWN     40000.0
# 7        5375  60 months     12.69         0.0           RENT     15000.0
# 8        6500  60 months     14.65         5.0            OWN     72000.0
# 9       12000  36 months     12.69        10.0            OWN     75000.0
# 10       9000  36 months     13.49         0.0           RENT     30000.0
# 11       3000  36 months      9.91         3.0           RENT     15000.0
#
#                purpose addr_state    dti  delinq_2yrs  revol_util  total_acc  \
# 0          credit_card         AZ  27.65          0.0        83.7        9.0
# 1                  car         GA   1.00          0.0         9.4        4.0
# 2       small_business         IL   8.72          0.0        98.5       10.0
# 3                other         CA  20.00          0.0        21.0       37.0
# 4              wedding         AZ  11.20          0.0        28.3       12.0
# 5                  car         CA   5.35          0.0        87.5        4.0
# 6       small_business         CA   5.55          0.0        32.6       13.0
# 7                other         TX  18.08          0.0        36.5        3.0
# 8   debt_consolidation         AZ  16.12          0.0        20.6       23.0
# 9   debt_consolidation         CA  10.78          0.0        67.1       34.0
# 10  debt_consolidation         VA  10.08          0.0        91.7        9.0
# 11         credit_card         IL  12.56          0.0        43.1       11.0
#
#     bad_loan  longest_credit_length verification_status
# 0          0                   26.0            verified
# 1          1                   12.0            verified
# 2          0                   10.0        not verified
# 3          0                   15.0            verified
# 4          0                    7.0            verified
# 5          0                    4.0            verified
# 6          1                    7.0            verified
# 7          1                    7.0            verified
# 8          0                   13.0        not verified
# 9          0                   22.0            verified
# 10         1                    7.0            verified
# 11         0                    8.0            verified

# %%
#Hiển thị 5 dòng cuối cùng của biến df_loan
df_loan.tail()

# %%
#Hiển thị kích thước df_loan (rows x columns)
df_loan.shape

# %%
#Danh sách tên các columns trong df
df_loan.columns

# %%
#Kiếm tra giá trị null trong Df
df_loan.isnull()
# Out:
#         loan_amnt   term  int_rate  emp_length  home_ownership  annual_inc  \
# 0           False  False     False       False           False       False
# 1           False  False     False       False           False       False
# 2           False  False     False       False           False       False
# 3           False  False     False       False           False       False
# 4           False  False     False       False           False       False
# ...           ...    ...       ...         ...             ...         ...
# 163982      False  False     False       False           False       False
# 163983      False  False     False       False           False       False
# 163984      False  False     False       False           False       False
# 163985      False  False     False       False           False       False
# 163986      False  False     False       False           False       False
#
#         purpose  addr_state    dti  delinq_2yrs  revol_util  total_acc  \
# 0         False       False  False        False       False      False
# 1         False       False  False        False       False      False
# 2         False       False  False        False       False      False
# 3         False       False  False        False       False      False
# 4         False       False  False        False       False      False
# ...         ...         ...    ...          ...         ...        ...
# 163982    False       False  False        False       False      False
# 163983    False       False  False        False       False      False
# 163984    False       False  False        False       False      False
# 163985    False       False  False        False       False      False
# 163986    False       False  False        False       False      False
#
#         bad_loan  longest_credit_length  verification_status
# 0          False                  False                False
# 1          False                  False                False
# 2          False                  False                False
# 3          False                  False                False
# 4          False                  False                False
# ...          ...                    ...                  ...
# 163982     False                  False                False
# 163983     False                  False                False
# 163984     False                  False                False
# 163985     False                  False                False
# 163986     False                  False                False
#
# [163987 rows x 15 columns]

# %%
#Thống kê số lượng null theo cột
df_loan.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# emp_length               5804
# home_ownership              0
# annual_inc                  4
# purpose                     0
# addr_state                  0
# dti                         0
# delinq_2yrs                29
# revol_util                193
# total_acc                  29
# bad_loan                    0
# longest_credit_length      29
# verification_status         0
# dtype: int64

# %%
#Cho biết số dòng dữ liệu không null
df_loan.count()
# Out:
# loan_amnt                163987
# term                     163987
# int_rate                 163987
# emp_length               158183
# home_ownership           163987
# annual_inc               163983
# purpose                  163987
# addr_state               163987
# dti                      163987
# delinq_2yrs              163958
# revol_util               163794
# total_acc                163958
# bad_loan                 163987
# longest_credit_length    163958
# verification_status      163987
# dtype: int64

# %%
#Số phần tử trong df (= rows x columns)
df_loan.size
# Out:
# 2459805

# %%
#Kiểu dữ liệu của từng columns trong df
df_loan.dtypes
# Out:
# loan_amnt                  int64
# term                      object
# int_rate                 float64
# emp_length               float64
# home_ownership            object
# annual_inc               float64
# purpose                   object
# addr_state                object
# dti                      float64
# delinq_2yrs              float64
# revol_util               float64
# total_acc                float64
# bad_loan                   int64
# longest_credit_length    float64
# verification_status       object
# dtype: object

# %%
#Quan sát một số đặc trưng thống kê của df
#Mặc định thống kê các cột dữ liệu số
df_loan.describe()
# Out:
#            loan_amnt       int_rate     emp_length    annual_inc  \
# count  163987.000000  163987.000000  158183.000000  1.639830e+05
# mean    13074.169141      13.715904       5.684353  7.191567e+04
# std      7993.556189       4.391940       3.610664  5.907092e+04
# min       500.000000       5.420000       0.000000  1.896000e+03
# 25%      7000.000000      10.650000       2.000000  4.500000e+04
# 50%     11325.000000      13.490000       6.000000  6.100000e+04
# 75%     18000.000000      16.320000      10.000000  8.500000e+04
# max     35000.000000      26.060000      10.000000  7.141778e+06
#
#                  dti    delinq_2yrs     revol_util      total_acc  \
# count  163987.000000  163958.000000  163794.000000  163958.000000
# mean       15.881530       0.227357      54.079173      24.579734
# std         7.587668       0.694168      25.285367      11.685190
# min         0.000000       0.000000       0.000000       1.000000
# 25%        10.230000       0.000000      35.600000      16.000000
# 50%        15.620000       0.000000      55.800000      23.000000
# 75%        21.260000       0.000000      74.200000      31.000000
# max        39.990000      29.000000     150.700000     118.000000
#
#             bad_loan  longest_credit_length
# count  163987.000000          163958.000000
# mean        0.183039              14.854274
# std         0.386700               6.947733
# min         0.000000               0.000000
# 25%         0.000000              10.000000
# 50%         0.000000              14.000000
# 75%         0.000000              18.000000
# max         1.000000              65.000000

# %%
df_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163987 entries, 0 to 163986
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   loan_amnt              163987 non-null  int64
#  1   term                   163987 non-null  object
#  2   int_rate               163987 non-null  float64
#  3   emp_length             158183 non-null  float64
#  4   home_ownership         163987 non-null  object
#  5   annual_inc             163983 non-null  float64
#  6   purpose                163987 non-null  object
#  7   addr_state             163987 non-null  object
#  8   dti                    163987 non-null  float64
#  9   delinq_2yrs            163958 non-null  float64
#  10  revol_util             163794 non-null  float64
#  11  total_acc              163958 non-null  float64
#  12  bad_loan               163987 non-null  int64
#  13  longest_credit_length  163958 non-null  float64
#  14  verification_status    163987 non-null  object
# dtypes: float64(8), int64(2), object(5)
# memory usage: 18.8+ MB

# %%
df_loan.head(10)
# Out:
#    loan_amnt       term  int_rate  emp_length home_ownership  annual_inc  \
# 0       5000  36 months     10.65        10.0           RENT     24000.0
# 1       2500  60 months     15.27         0.0           RENT     30000.0
# 2       2400  36 months     15.96        10.0           RENT     12252.0
# 3      10000  36 months     13.49        10.0           RENT     49200.0
# 4       5000  36 months      7.90         3.0           RENT     36000.0
# 5       3000  36 months     18.64         9.0           RENT     48000.0
# 6       5600  60 months     21.28         4.0            OWN     40000.0
# 7       5375  60 months     12.69         0.0           RENT     15000.0
# 8       6500  60 months     14.65         5.0            OWN     72000.0
# 9      12000  36 months     12.69        10.0            OWN     75000.0
#
#               purpose addr_state    dti  delinq_2yrs  revol_util  total_acc  \
# 0         credit_card         AZ  27.65          0.0        83.7        9.0
# 1                 car         GA   1.00          0.0         9.4        4.0
# 2      small_business         IL   8.72          0.0        98.5       10.0
# 3               other         CA  20.00          0.0        21.0       37.0
# 4             wedding         AZ  11.20          0.0        28.3       12.0
# 5                 car         CA   5.35          0.0        87.5        4.0
# 6      small_business         CA   5.55          0.0        32.6       13.0
# 7               other         TX  18.08          0.0        36.5        3.0
# 8  debt_consolidation         AZ  16.12          0.0        20.6       23.0
# 9  debt_consolidation         CA  10.78          0.0        67.1       34.0
#
#    bad_loan  longest_credit_length verification_status
# 0         0                   26.0            verified
# 1         1                   12.0            verified
# 2         0                   10.0        not verified
# 3         0                   15.0            verified
# 4         0                    7.0            verified
# 5         0                    4.0            verified
# 6         1                    7.0            verified
# 7         1                    7.0            verified
# 8         0                   13.0        not verified
# 9         0                   22.0            verified

# %%
#Quan sát một số đặc trưng thống kê của df
#Thống kê các cột dữ liệu Object
df_loan.describe(include='O')
# Out:
#              term home_ownership             purpose addr_state  \
# count      163987         163987              163987     163987
# unique          2              6                  14         50
# top     36 months       MORTGAGE  debt_consolidation         CA
# freq       129950          79714               93261      28702
#
#        verification_status
# count               163987
# unique                   2
# top               verified
# freq                104832

# %%
#Thống kê tất cả các cột dữ liệu ko phân biệt số, object
df_loan.describe(include='all')
# Out:
#             loan_amnt       term       int_rate     emp_length home_ownership  \
# count   163987.000000     163987  163987.000000  158183.000000         163987
# unique            NaN          2            NaN            NaN              6
# top               NaN  36 months            NaN            NaN       MORTGAGE
# freq              NaN     129950            NaN            NaN          79714
# mean     13074.169141        NaN      13.715904       5.684353            NaN
# std       7993.556189        NaN       4.391940       3.610664            NaN
# min        500.000000        NaN       5.420000       0.000000            NaN
# 25%       7000.000000        NaN      10.650000       2.000000            NaN
# 50%      11325.000000        NaN      13.490000       6.000000            NaN
# 75%      18000.000000        NaN      16.320000      10.000000            NaN
# max      35000.000000        NaN      26.060000      10.000000            NaN
#
#           annual_inc             purpose addr_state            dti  \
# count   1.639830e+05              163987     163987  163987.000000
# unique           NaN                  14         50            NaN
# top              NaN  debt_consolidation         CA            NaN
# freq             NaN               93261      28702            NaN
# mean    7.191567e+04                 NaN        NaN      15.881530
# std     5.907092e+04                 NaN        NaN       7.587668
# min     1.896000e+03                 NaN        NaN       0.000000
# 25%     4.500000e+04                 NaN        NaN      10.230000
# 50%     6.100000e+04                 NaN        NaN      15.620000
# 75%     8.500000e+04                 NaN        NaN      21.260000
# max     7.141778e+06                 NaN        NaN      39.990000
#
#           delinq_2yrs     revol_util      total_acc       bad_loan  \
# count   163958.000000  163794.000000  163958.000000  163987.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         0.227357      54.079173      24.579734       0.183039
# std          0.694168      25.285367      11.685190       0.386700
# min          0.000000       0.000000       1.000000       0.000000
# 25%          0.000000      35.600000      16.000000       0.000000
# 50%          0.000000      55.800000      23.000000       0.000000
# 75%          0.000000      74.200000      31.000000       0.000000
# max         29.000000     150.700000     118.000000       1.000000
#
#         longest_credit_length verification_status
# count           163958.000000              163987
# unique                    NaN                   2
# top                       NaN            verified
# freq                      NaN              104832
# mean                14.854274                 NaN
# std                  6.947733                 NaN
# min                  0.000000                 NaN
# 25%                 10.000000                 NaN
# 50%                 14.000000                 NaN
# 75%                 18.000000                 NaN
# max                 65.000000                 NaN

# %%
#Quan sát đặc trưng thống kê theo từng cột
#Dữ liệu số
df_loan[['loan_amnt']].describe()
# Out:
#            loan_amnt
# count  163987.000000
# mean    13074.169141
# std      7993.556189
# min       500.000000
# 25%      7000.000000
# 50%     11325.000000
# 75%     18000.000000
# max     35000.000000

# %%
#Quan sát đặc trưng thống kê theo từng cột
#Dữ liệu Object
df_loan[['term']].describe()
# Out:
#              term
# count      163987
# unique          2
# top     36 months
# freq       129950

# %% [markdown]
# ## 3.2) Truy xuất dữ liệu trong DataFrame
# ---

# %%
#Truy xuất dữ liệu theo cột
#Lấy dữ liệu của một cột
df_state = df_loan[['addr_state']]
df_state.head()
# Out:
#   addr_state
# 0         AZ
# 1         GA
# 2         IL
# 3         CA
# 4         AZ

# %%
#Truy xuất dữ liệu theo cột
#Chỉ lấy dữ liệu của 3 cột: loan_amnt, int_rate, purpose
df_loan1 = df_loan[['loan_amnt','int_rate','purpose']]
df_loan1.head()
# Out:
#    loan_amnt  int_rate         purpose
# 0       5000     10.65     credit_card
# 1       2500     15.27             car
# 2       2400     15.96  small_business
# 3      10000     13.49           other
# 4       5000      7.90         wedding

# %% [markdown]
# #### df.iloc[[index_row],[index_col]]: Truy cập tới dữ liệu của hàng và cột qua chỉ số index_row, index_col (tương tự như với Numpy)

# %%
#Sử dụng .iloc truy xuất dữ liệu như với Numpy
#Truy xuất 10 dòng dữ liệu từ [10 --> 20) tất cả các cột --- index = 0
df_loan.iloc[10:20,2:5]
# Out:
#     int_rate  emp_length home_ownership
# 10     13.49         0.0           RENT
# 11      9.91         3.0           RENT
# 12     10.65         3.0           RENT
# 13     16.29         0.0           RENT
# 14     15.27         4.0           RENT
# 15      6.03        10.0       MORTGAGE
# 16     11.71         1.0       MORTGAGE
# 17      6.03         6.0           RENT
# 18     12.42        10.0           RENT
# 19     11.71        10.0            OWN

# %%
#Truy xuất 100 dòng dữ liệu đầu tiên,
#của các cột có index 0, 4, 6, 7
df_loan.iloc[:100,[0,4,6,7]]
# Out:
#     loan_amnt home_ownership             purpose addr_state
# 0        5000           RENT         credit_card         AZ
# 1        2500           RENT                 car         GA
# 2        2400           RENT      small_business         IL
# 3       10000           RENT               other         CA
# 4        5000           RENT             wedding         AZ
# ..        ...            ...                 ...        ...
# 95      24000           RENT  debt_consolidation         CA
# 96       6000           RENT  debt_consolidation         CA
# 97       6000           RENT  debt_consolidation         AZ
# 98       2100       MORTGAGE            vacation         LA
# 99       5500       MORTGAGE      small_business         CT
#
# [100 rows x 4 columns]

# %%
#Truy cập dòng dữ liệu 10, cột 7
df_loan.iloc[4,0]
# Out:
# 5000

# %%
#Truy cập dòng dữ liệu 10, dòng 7
#Cột dữ liệu 0, 1, 5
df_loan.iloc[[10,7],[0,1,5]]
# Out:
#     loan_amnt       term  annual_inc
# 10       9000  36 months     30000.0
# 7        5375  60 months     15000.0

# %% [markdown]
# #### df.loc[[index_row],[name_col]]: Truy cập tới dữ liệu của hàng và cột qua chỉ số index_row, tên cột name_col

# %%
#Truy cập từ dòng có index 20 đến dòng 25 của df
#chỉ lấy dữ liệu 4 cột: loan_amnt, home_ownership, purpose, addr_state
df_loan.loc[20:25,['loan_amnt','home_ownership','purpose','addr_state']]
# Out:
#     loan_amnt home_ownership             purpose addr_state
# 20      10000           RENT  debt_consolidation         CA
# 21       6000           RENT      major_purchase         CA
# 22      15000       MORTGAGE         credit_card         IL
# 23      15000           RENT  debt_consolidation         NY
# 24       5000           RENT               other         PA
# 25       4000       MORTGAGE  debt_consolidation         FL

# %% [markdown]
# # 4) Replacing Values and Renamde Columns
# ---
# ## 4.1) Replacing values

# %%
#tách lấy dataframe để thực hiện replacing values
df_new = df_loan.loc[:10,['loan_amnt',
                          'home_ownership',
                          'purpose',
                          'addr_state']]
df_new
# Out:
#     loan_amnt home_ownership             purpose addr_state
# 0        5000           RENT         credit_card         AZ
# 1        2500           RENT                 car         GA
# 2        2400           RENT      small_business         IL
# 3       10000           RENT               other         CA
# 4        5000           RENT             wedding         AZ
# 5        3000           RENT                 car         CA
# 6        5600            OWN      small_business         CA
# 7        5375           RENT               other         TX
# 8        6500            OWN  debt_consolidation         AZ
# 9       12000            OWN  debt_consolidation         CA
# 10       9000           RENT  debt_consolidation         VA

# %%
#Thay thế giá trị purpose: credit_card--> wedding
#của index đầu tiên
df_new.loc[0,'purpose'] = 'wedding'
df_new
# Out:
#     loan_amnt home_ownership             purpose addr_state
# 0        5000           RENT             wedding         AZ
# 1        2500           RENT                 car         GA
# 2        2400           RENT      small_business         IL
# 3       10000           RENT               other         CA
# 4        5000           RENT             wedding         AZ
# 5        3000           RENT                 car         CA
# 6        5600            OWN      small_business         CA
# 7        5375           RENT               other         TX
# 8        6500            OWN  debt_consolidation         AZ
# 9       12000            OWN  debt_consolidation         CA
# 10       9000           RENT  debt_consolidation         VA

# %%
#Thay thế giá trị thuộc tính loan_amnt: 2400 --> 8800
#của index = 2
df_new.iloc[2,0] = 8800
df_new
# Out:
#     loan_amnt home_ownership             purpose addr_state
# 0        5000           RENT             wedding         AZ
# 1        2500           RENT                 car         GA
# 2        8800           RENT      small_business         IL
# 3       10000           RENT               other         CA
# 4        5000           RENT             wedding         AZ
# 5        3000           RENT                 car         CA
# 6        5600            OWN      small_business         CA
# 7        5375           RENT               other         TX
# 8        6500            OWN  debt_consolidation         AZ
# 9       12000            OWN  debt_consolidation         CA
# 10       9000           RENT  debt_consolidation         VA

# %%
#Thay thế nhiều giá trị trong DataFrame
#RENT --> MORTGAGE
#car --> small_business
df_new.replace({'RENT':'MORTGAGE',
                'car':'small_business'})
# Out:
#     loan_amnt home_ownership             purpose addr_state
# 0        5000       MORTGAGE             wedding         AZ
# 1        2500       MORTGAGE      small_business         GA
# 2        8800       MORTGAGE      small_business         IL
# 3       10000       MORTGAGE               other         CA
# 4        5000       MORTGAGE             wedding         AZ
# 5        3000       MORTGAGE      small_business         CA
# 6        5600            OWN      small_business         CA
# 7        5375       MORTGAGE               other         TX
# 8        6500            OWN  debt_consolidation         AZ
# 9       12000            OWN  debt_consolidation         CA
# 10       9000       MORTGAGE  debt_consolidation         VA

# %%
df_new
# Out:
#     loan_amnt home_ownership             purpose addr_state
# 0        5000           RENT             wedding         AZ
# 1        2500           RENT                 car         GA
# 2        8800           RENT      small_business         IL
# 3       10000           RENT               other         CA
# 4        5000           RENT             wedding         AZ
# 5        3000           RENT                 car         CA
# 6        5600            OWN      small_business         CA
# 7        5375           RENT               other         TX
# 8        6500            OWN  debt_consolidation         AZ
# 9       12000            OWN  debt_consolidation         CA
# 10       9000           RENT  debt_consolidation         VA

# %%
#Khi muốn thay đổi áp dụng lên DataFrame hiện tại
#Thiết lập tham số inplace=True
df_new.replace({'RENT':'MORTGAGE',
                'car':'small_business'}, inplace=True)
df_new
# Out:
#     loan_amnt home_ownership             purpose addr_state
# 0        5000       MORTGAGE             wedding         AZ
# 1        2500       MORTGAGE      small_business         GA
# 2        8800       MORTGAGE      small_business         IL
# 3       10000       MORTGAGE               other         CA
# 4        5000       MORTGAGE             wedding         AZ
# 5        3000       MORTGAGE      small_business         CA
# 6        5600            OWN      small_business         CA
# 7        5375       MORTGAGE               other         TX
# 8        6500            OWN  debt_consolidation         AZ
# 9       12000            OWN  debt_consolidation         CA
# 10       9000       MORTGAGE  debt_consolidation         VA

# %%
df_new.replace({5000:8000}, inplace=True)
df_new
# Out:
#     loan_amnt home_ownership             purpose addr_state
# 0        8000       MORTGAGE             wedding         AZ
# 1        2500       MORTGAGE      small_business         GA
# 2        8800       MORTGAGE      small_business         IL
# 3       10000       MORTGAGE               other         CA
# 4        8000       MORTGAGE             wedding         AZ
# 5        3000       MORTGAGE      small_business         CA
# 6        5600            OWN      small_business         CA
# 7        5375       MORTGAGE               other         TX
# 8        6500            OWN  debt_consolidation         AZ
# 9       12000            OWN  debt_consolidation         CA
# 10       9000       MORTGAGE  debt_consolidation         VA

# %%
#Thay thế tên viết tắt bằng tên đầy đủ.
state_name={'AZ':'Arizona',
            'GA':'Georgia',
            'IL':'Illinois',
            'CA':'California',
            'TX':'Texas',
            'VA':'Virgrinia'}
#Trong cột addr_state
df_new['addr_state'].replace(state_name,inplace=True)
df_new
# Out:
#     loan_amnt home_ownership             purpose  addr_state
# 0        8000       MORTGAGE             wedding     Arizona
# 1        2500       MORTGAGE      small_business     Georgia
# 2        8800       MORTGAGE      small_business    Illinois
# 3       10000       MORTGAGE               other  California
# 4        8000       MORTGAGE             wedding     Arizona
# 5        3000       MORTGAGE      small_business  California
# 6        5600            OWN      small_business  California
# 7        5375       MORTGAGE               other       Texas
# 8        6500            OWN  debt_consolidation     Arizona
# 9       12000            OWN  debt_consolidation  California
# 10       9000       MORTGAGE  debt_consolidation   Virgrinia

# %% [markdown]
# ## 4.2) Thay đổi tên cột trong DataFrame
# ---

# %%
df_new = df_loan[['loan_amnt','home_ownership','purpose','addr_state']].copy()
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163987 entries, 0 to 163986
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   loan_amnt       163987 non-null  int64
#  1   home_ownership  163987 non-null  object
#  2   purpose         163987 non-null  object
#  3   addr_state      163987 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 5.0+ MB

# %%
#Đổi tên cột
t = df_new.rename(columns={'loan_amnt':'Số tiền vay',
                       'home_ownership':'Tình trạng nhà ở',
                       'purpose': ' Mục đích vay tiền',
                       'addr_state':'Địa chỉ'})
t.head()
# Out:
#    Số tiền vay Tình trạng nhà ở  Mục đích vay tiền Địa chỉ
# 0         5000             RENT        credit_card      AZ
# 1         2500             RENT                car      GA
# 2         2400             RENT     small_business      IL
# 3        10000             RENT              other      CA
# 4         5000             RENT            wedding      AZ

# %%
#Muốn áp dụng thay đổi vào trực tiếp biến df, sử dụng inplace=True
df_new.rename(columns={'loan_amnt':'Số tiền vay',
                       'home_ownership':'Tình trạng nhà ở',
                       'purpose': ' Mục đích vay tiền',
                       'addr_state':'Địa chỉ'}, inplace=True)
df_new.head()
# Out:
#    Số tiền vay Tình trạng nhà ở  Mục đích vay tiền Địa chỉ
# 0         5000             RENT        credit_card      AZ
# 1         2500             RENT                car      GA
# 2         2400             RENT     small_business      IL
# 3        10000             RENT              other      CA
# 4         5000             RENT            wedding      AZ

# %%
#Đổi tên cột sang viết hoa
df_new.rename(str.upper, axis='columns')
# Out:
#         SỐ TIỀN VAY TÌNH TRẠNG NHÀ Ở   MỤC ĐÍCH VAY TIỀN ĐỊA CHỈ
# 0              5000             RENT         credit_card      AZ
# 1              2500             RENT                 car      GA
# 2              2400             RENT      small_business      IL
# 3             10000             RENT               other      CA
# 4              5000             RENT             wedding      AZ
# ...             ...              ...                 ...     ...
# 163982        15000         MORTGAGE         credit_card      OK
# 163983        20000              OWN    home_improvement      VA
# 163984        12825         MORTGAGE  debt_consolidation      TX
# 163985        27650             RENT         credit_card      NY
# 163986        17000         MORTGAGE  debt_consolidation      PA
#
# [163987 rows x 4 columns]

# %%
df_new
# Out:
#         Số tiền vay Tình trạng nhà ở   Mục đích vay tiền Địa chỉ
# 0              5000             RENT         credit_card      AZ
# 1              2500             RENT                 car      GA
# 2              2400             RENT      small_business      IL
# 3             10000             RENT               other      CA
# 4              5000             RENT             wedding      AZ
# ...             ...              ...                 ...     ...
# 163982        15000         MORTGAGE         credit_card      OK
# 163983        20000              OWN    home_improvement      VA
# 163984        12825         MORTGAGE  debt_consolidation      TX
# 163985        27650             RENT         credit_card      NY
# 163986        17000         MORTGAGE  debt_consolidation      PA
#
# [163987 rows x 4 columns]

# %% [markdown]
# ## Thực hành 1
# ---
# **Yêu cầu 1.1:**
# 1. Đọc dữ liệu từ file .csv vào biến kiểu dataframe: df_patient với cột đầu tiên (id) là cột chỉ số (index_col)
# 2. Hiển thị thông tin tổng quan của tập dữ liệu
# 3. Hiển thị thông tin của 10 bệnh nhân đầu tiên và 5 bệnh nhân cuối cùng của tập dữ liệu.
# 4. Đặt lại tên các cột dữ liệu trong Dataframe:
#     * Feature_1 --> Age
#     * Feature_2 --> Gender
#     * Feature_3 --> Type
#     * Feature_4 --> Blood_pressure
#     * Feature_5 --> Cholesterol
#     * Feature_6 --> Heartbeat
#     * Feature_7 --> Thalassemia
#     * Feature_8 --> Result

# %%
#{VIẾT CODE Ở ĐÂY}
import pandas as pd
path='D:/hoctap/datatrainningpython/Data_Patient.csv'
pd_path_csv=pd.read_csv(path)
pd_path_csv
# Out:
#               id  feature_1 feature_2         feature_3  feature_4  feature_5  \
# 0     Patient_01         63      Male    Typical angina        145        233
# 1     Patient_02         67      Male      Asymptomatic        160        286
# 2     Patient_03         67      Male      Asymptomatic        120        229
# 3     Patient_04         37      Male  Non-anginal pain        130        250
# 4     Patient_05         41    Female   Atypical angina        130        204
# ..           ...        ...       ...               ...        ...        ...
# 295  Patient_296         59      Male      Asymptomatic        164        176
# 296  Patient_297         57    Female      Asymptomatic        140        241
# 297  Patient_298         45      Male    Typical angina        110        264
# 298  Patient_299         68      Male      Asymptomatic        144        193
# 299  Patient_300         57      Male      Asymptomatic        130        131
#
#      feature_6  feature_7  feature_8
# 0          150        6.0          0
# 1          108        3.0          1
# 2          129        7.0          1
# 3          187        3.0          0
# 4          172        NaN          0
# ..         ...        ...        ...
# 295         90        6.0          1
# 296        123        7.0          1
# 297        132        7.0          1
# 298        141        7.0          1
# 299        115        7.0          1
#
# [300 rows x 9 columns]

# %%
pd_path_csv.head(10)
# Out:
#            id  feature_1 feature_2         feature_3  feature_4  feature_5  \
# 0  Patient_01         63      Male    Typical angina        145        233
# 1  Patient_02         67      Male      Asymptomatic        160        286
# 2  Patient_03         67      Male      Asymptomatic        120        229
# 3  Patient_04         37      Male  Non-anginal pain        130        250
# 4  Patient_05         41    Female   Atypical angina        130        204
# 5  Patient_06         56      Male   Atypical angina        120        236
# 6  Patient_07         62    Female      Asymptomatic        140        268
# 7  Patient_08         57    Female      Asymptomatic        120        354
# 8  Patient_09         63      Male      Asymptomatic        130        254
# 9  Patient_10         53      Male      Asymptomatic        140        203
#
#    feature_6  feature_7  feature_8
# 0        150        6.0          0
# 1        108        3.0          1
# 2        129        7.0          1
# 3        187        3.0          0
# 4        172        NaN          0
# 5        178        3.0          0
# 6        160        3.0          1
# 7        163        3.0          0
# 8        147        7.0          1
# 9        155        7.0          1

# %%
pd_path_csv.tail(5)
# Out:
#               id  feature_1 feature_2       feature_3  feature_4  feature_5  \
# 295  Patient_296         59      Male    Asymptomatic        164        176
# 296  Patient_297         57    Female    Asymptomatic        140        241
# 297  Patient_298         45      Male  Typical angina        110        264
# 298  Patient_299         68      Male    Asymptomatic        144        193
# 299  Patient_300         57      Male    Asymptomatic        130        131
#
#      feature_6  feature_7  feature_8
# 295         90        6.0          1
# 296        123        7.0          1
# 297        132        7.0          1
# 298        141        7.0          1
# 299        115        7.0          1

# %%
path_new=pd_path_csv.rename(columns={'feature_1':'Age',
                            'feature_2':'Gende',
                            'feature_3':'Type',
                            'feature_4':'Blood_pressure',
                            'feature_5':'Cholesterol',
                            'feature_6':'Heartbeat',
                            'feature_7':'Thalassemia',
                            'feature_8':'Result'})
path_new
# Out:
#               id  Age   Gende              Type  blood_presure  Cholesterol  \
# 0     Patient_01   63    Male    Typical angina            145          233
# 1     Patient_02   67    Male      Asymptomatic            160          286
# 2     Patient_03   67    Male      Asymptomatic            120          229
# 3     Patient_04   37    Male  Non-anginal pain            130          250
# 4     Patient_05   41  Female   Atypical angina            130          204
# ..           ...  ...     ...               ...            ...          ...
# 295  Patient_296   59    Male      Asymptomatic            164          176
# 296  Patient_297   57  Female      Asymptomatic            140          241
# 297  Patient_298   45    Male    Typical angina            110          264
# 298  Patient_299   68    Male      Asymptomatic            144          193
# 299  Patient_300   57    Male      Asymptomatic            130          131
#
#      Heartbeat  Thalassemia  Result
# 0          150          6.0       0
# 1          108          3.0       1
# 2          129          7.0       1
# 3          187          3.0       0
# 4          172          NaN       0
# ..         ...          ...     ...
# 295         90          6.0       1
# 296        123          7.0       1
# 297        132          7.0       1
# 298        141          7.0       1
# 299        115          7.0       1
#
# [300 rows x 9 columns]

# %% [markdown]
# **Yêu cầu 1.2:**
# Sử dụng phương thức .describe() cho biết:
#
#     * Thuộc tính Age:
#         - Tuổi của bệnh nhân trẻ nhất
#         - Tuổi của bệnh nhân già nhất
#     * Thuộc tính Cholesterol:
#         - Cholesterol trung bình của các bệnh nhân
#         - Độ lệch chuẩn của giá trị này trong toàn bộ tập dữ liệu
#     * Bao nhiêu bệnh nhân giới tính nam (Male)
#     * Có bao nhiêu giá trị khác nhau của thuộc tính Type. Giá trị xuất hiện nhiều nhất là giá trị nào, bao nhiêu lần.

# %%
#{VIẾT CODE Ở ĐÂY}
import pandas as pd
path='D:/hoctap/datatrainningpython/Data_Patient.csv'
pd_path_csv=pd.read_csv(path)
pd_path_csv.rename(columns={'feature_1':'Age',
                            'feature_2':'Gende',
                            'feature_3':'Type',
                            'feature_4':'Blood_pressure',
                            'feature_5':'Cholesterol',
                            'feature_6':'Heartbeat',
                            'feature_7':'Thalassemia',
                            'feature_8':'Result'}, inplace=True)

pd_path_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              300 non-null    object
#  1   Age             300 non-null    int64
#  2   Gende           300 non-null    object
#  3   Type            295 non-null    object
#  4   Blood_pressure  300 non-null    int64
#  5   Cholesterol     300 non-null    int64
#  6   Heartbeat       300 non-null    int64
#  7   Thalassemia     293 non-null    float64
#  8   Result          300 non-null    int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 21.2+ KB

# %%
print("tuoi thap nhat",pd_path_csv.Age.min())
# Out:
# tuoi thap nhat 29

# %%
pd_path_csv.Age.max()
# Out:
# 77

# %%
pd_path_csv.Cholesterol.mean()
# Out:
# 247.07

# %%
pd_path_csv.Cholesterol.std()
# Out:
# 51.835136454315

# %% [markdown]
# **Yêu cầu 1.3:**
#
# Cho biết những cột nào trong dữ liệu có chứa missing data và số lượng missing là bao nhiêu?

# %%
#{VIẾT CODE Ở ĐÂY}
pd_path_csv.isnull()
# Out:
#         id    Age  Gende   Type  Blood_pressure  Cholesterol  Heartbeat  \
# 0    False  False  False  False           False        False      False
# 1    False  False  False  False           False        False      False
# 2    False  False  False  False           False        False      False
# 3    False  False  False  False           False        False      False
# 4    False  False  False  False           False        False      False
# ..     ...    ...    ...    ...             ...          ...        ...
# 295  False  False  False  False           False        False      False
# 296  False  False  False  False           False        False      False
# 297  False  False  False  False           False        False      False
# 298  False  False  False  False           False        False      False
# 299  False  False  False  False           False        False      False
#
#      Thalassemia  Result
# 0          False   False
# 1          False   False
# 2          False   False
# 3          False   False
# 4           True   False
# ..           ...     ...
# 295        False   False
# 296        False   False
# 297        False   False
# 298        False   False
# 299        False   False
#
# [300 rows x 9 columns]

# %%
pd_path_csv.isnull().sum()
# Out:
# id           0
# feature_1    0
# feature_2    0
# feature_3    5
# feature_4    0
# feature_5    0
# feature_6    0
# feature_7    7
# feature_8    0
# dtype: int64

# %% [markdown]
# **Yêu cầu 1.4:**
# Hiển thị thông tin của các bệnh nhân:
#    * Bệnh nhân có index: Patient_100; Patient_150; Patient_200
#    * Bệnh nhân ở vị trí 255 đến 260, với 3 thuộc tính: Age, Gender và Result

# %%
#{VIẾT CODE Ở ĐÂY}
import pandas as pd
path='D:/hoctap/datatrainningpython/Data_Patient.csv'
pd_path_csv=pd.read_csv(path)
pd_path_csv.rename(columns={'feature_1':'Age',
                            'feature_2':'Gender',
                            'feature_3':'Type',
                            'feature_4':'Blood_pressure',
                            'feature_5':'Cholesterol',
                            'feature_6':'Heartbeat',
                            'feature_7':'Thalassemia',
                            'feature_8':'Result'}, inplace=True)
#pd_path_csv.head()
pd_path_csv.loc[256:260,['Age','Gender','Result']]
# Out:
#      Age  Gender  Result
# 256   76  Female       0
# 257   70    Male       0
# 258   57    Male       1
# 259   44  Female       0
# 260   58  Female       1

# %%
pd_path_csv.iloc[[99,149,199],0:]
# Out:
#               id  Age  Gender            Type  Blood_pressure  Cholesterol  \
# 99   Patient_100   45    Male    Asymptomatic             115          260
# 149  Patient_150   52    Male  Typical angina             152          298
# 199  Patient_200   50  Female    Asymptomatic             110          254
#
#      Heartbeat  Thalassemia  Result
# 99         185          3.0       0
# 149        178          7.0       0
# 199        159          3.0       0

# %% [markdown]
# **Yêu cầu 1.5:**
# 1. Thay đổi giá trị cho thuộc tính Gender: Male --> 0, Female --> 1
# 2. Thay đổi giá trị cho thuộc tính Result: 0 --> No, 1 --> Yes
# 3. Cập nhật giá trị thuộc tính Thalassemia của bệnh nhân có index: Patient_05 bằng giá trị 4.0

# %%
#{VIẾT CODE Ở ĐÂY}

string={'Male':'0', 'Female':'1'}
pd_path_csv['Gender'].replace(string,inplace=True)
pd_path_csv['Result'].replace({'0':'NO',
                              '1':'YES'},inplace=True)

# %%
state_name={'AZ':'Arizona',
            'GA':'Georgia',
            'IL':'Illinois',
            'CA':'California',
            'TX':'Texas',
            'VA':'Virgrinia'}
#Trong cột addr_state
df_new['addr_state'].replace(state_name,inplace=True)
df_new

# %% [markdown]
# ## 5) Filter Data
# ---

# %%
path = 'D:/hoctap/datatrainningpython/csv_Data_BMI.csv'
df_bmi = pd.read_csv(path)
df_bmi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Personal   500 non-null    object
#  1   Gender     500 non-null    object
#  2   Height_cm  500 non-null    int64
#  3   Weight_kg  500 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 15.8+ KB

# %%
df_bmi.head()
# Out:
#            id  feature_1 feature_2         feature_3  feature_4  feature_5  \
# 0  Patient_01         63      Male    Typical angina        145        233
# 1  Patient_02         67      Male      Asymptomatic        160        286
# 2  Patient_03         67      Male      Asymptomatic        120        229
# 3  Patient_04         37      Male  Non-anginal pain        130        250
# 4  Patient_05         41    Female   Atypical angina        130        204
#
#    feature_6  feature_7  feature_8
# 0        150        6.0          0
# 1        108        3.0          1
# 2        129        7.0          1
# 3        187        3.0          0
# 4        172        NaN          0

# %%
#lọc danh sách người giới tính nam
#Cách 1:
df_male1 = df_bmi[df_bmi.Gender=='Male']
df_male1.head()
# Out:
#   Personal Gender  Height_cm  Weight_kg
# 0       P1   Male        174         96
# 1       P2   Male        189         87
# 4       P5   Male        149         61
# 5       P6   Male        189        104
# 6       P7   Male        147         92

# %%
#Cách 2: sử dụng phương thức query
df_male2 = df_bmi.query('Gender=="Male"')
df_male2.head()
# Out:
#   Personal Gender  Height_cm  Weight_kg
# 0       P1   Male        174         96
# 1       P2   Male        189         87
# 4       P5   Male        149         61
# 5       P6   Male        189        104
# 6       P7   Male        147         92

# %%
#Cách 3: sử dụng iloc
df_male3 = df_bmi.loc[(df_bmi.Gender=="Male")]
df_male3.head()
# Out:
#   Personal Gender  Height_cm  Weight_kg
# 0       P1   Male        174         96
# 1       P2   Male        189         87
# 4       P5   Male        149         61
# 5       P6   Male        189        104
# 6       P7   Male        147         92

# %%
#Kết hợp nhiều tiêu chí lọc dữ liệu
#lọc người có giới tính Femal và cân nặng dưới 70kg
df_p1 = df_bmi[(df_bmi.Gender =='Female') & (df_bmi.Weight_kg<70)]
df_p1
# Out:
#     Personal  Gender  Height_cm  Weight_kg
# 24       P25  Female        172         67
# 25       P26  Female        151         64
# 32       P33  Female        195         65
# 51       P52  Female        176         54
# 60       P61  Female        191         54
# 67       P68  Female        168         59
# 70       P71  Female        153         51
# 99      P100  Female        190         50
# 116     P117  Female        165         57
# 140     P141  Female        169         54
# 150     P151  Female        196         50
# 152     P153  Female        150         60
# 168     P169  Female        151         67
# 209     P210  Female        148         67
# 214     P215  Female        185         52
# 238     P239  Female        174         65
# 244     P245  Female        183         50
# 255     P256  Female        162         58
# 263     P264  Female        157         52
# 273     P274  Female        163         57
# 288     P289  Female        156         52
# 292     P293  Female        162         68
# 313     P314  Female        179         67
# 314     P315  Female        180         60
# 324     P325  Female        144         66
# 325     P326  Female        148         54
# 333     P334  Female        172         62
# 334     P335  Female        157         56
# 346     P347  Female        191         68
# 349     P350  Female        157         60
# 352     P353  Female        160         51
# 358     P359  Female        180         58
# 360     P361  Female        193         61
# 369     P370  Female        147         67
# 373     P374  Female        163         63
# 388     P389  Female        157         66
# 389     P390  Female        150         50
# 390     P391  Female        167         58
# 398     P399  Female        149         61
# 417     P418  Female        162         64
# 419     P420  Female        177         61
# 420     P421  Female        195         61
# 425     P426  Female        180         59
# 472     P473  Female        178         65
# 478     P479  Female        151         55
# 490     P491  Female        164         59
# 492     P493  Female        198         50
# 493     P494  Female        170         53

# %%
#Kết hợp nhiều tiêu chí lọc dữ liệu
#lọc người có chiều cao > 195 cm hoặc cân nặng > 150kg
df_p2 = df_bmi[(df_bmi.Height_cm >195) | (df_bmi.Weight_kg>150)]
df_p2

# %%
# toán tử ~ - Not
df_p3 = df_bmi[~(df_bmi.Weight_kg<155)]
df_p3

# %%
#Lọc ra những người có cân nặng bằng 150, 155 và 160kg
# phương thức isin (tương tự như in)
df_p4 = df_bmi[df_bmi.Weight_kg.isin([150,155,160])]
df_p4

# %%
df_bmi[df_bmi.Weight_kg.isin([150,155,160])].count()

# %% [markdown]
# ## 6) Đặc trưng thống kê
# ---

# %%
#Tính tổng theo cột chiều cao
df_bmi['Height_cm'].sum()

# %%
#Tính tổng trong toàn bộ DataFrame
df_bmi.sum()

# %%
#tìm Max, Min của thuộc tính cân nặng
w_max = df_bmi['Weight_kg'].max()
w_min = df_bmi['Weight_kg'].min()
print('Cân nặng lớn nhất:',w_max, '(kg)')
print('Cân nặng nhỏ nhất:',w_min, '(kg)')

# %%
#tìm Max, Min của thuộc tính cân nặng
w_max = df_bmi['Height_cm'].max()
w_min = df_bmi['Height_cm'].min()
print('Chiều cao lớn nhất:',w_max, '(cm)')
print('Chiều cao nhỏ nhất:',w_min, '(cm)')

# %%
#cộng dồn giá trị các phần tử theo hàng
df_bmi['Weight_kg'].cumsum()

# %%
#tìm Mean, Median
w_mean = df_bmi['Weight_kg'].mean()
w_median = df_bmi['Weight_kg'].median()
print('Cân nặng trung bình:',w_mean, '(kg)')
print('trung vị:',w_median, '(kg)')

# %%
#tìm Mean, Median của chiều cao
h_mean = df_bmi['Height_cm'].mean()
h_median = df_bmi['Height_cm'].median()
print('Chiều cao trung bình:',h_mean, '(cm)')
print('Trung vị:',h_median, '(cm)')

# %%
#tìm độ lệch chuẩn của chiều cao, cân nặng
h_std = df_bmi['Height_cm'].std()
w_std = df_bmi['Weight_kg'].std()
print('sdt của chiều cao:', h_std)
print('sdt của cân nặng:', w_std)

# %% [markdown]
# ## 7) Unique
# ---

# %%
#Xác định giá trị duy nhất trong một cột
df_bmi['Gender'].unique()

# %%
#Thống kê số lượng theo giá trị duy nhất
unique_gender = df_bmi['Gender'].value_counts()
unique_gender
# Out:
# Female    255
# Male      245
# Name: Gender, dtype: int64

# %%
#Vẽ đồ thị thể hiện kết quả 
import 
plt.bar(unique_gender.index, unique_gender.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-0befdd2719d0> in <module>
#       1 #Vẽ đồ thị thể hiện kết quả
# ----> 2 plt.bar(unique_gender.index, unique_gender.values)
#
# NameError: name 'plt' is not defined

# %%
#Thống kê theo cân nặng
unique_weight = df_bmi['Weight_kg'].value_counts()
unique_weight

# %%
type(unique_weight)

# %%
plt.bar(unique_weight.index,unique_weight.values)

# %% [markdown]
# # THỰC HÀNH 2:
# ---
# **Yêu cầu 1.1:**
# 1. Đọc dữ liệu từ file .csv vào biến kiểu dataframe: df_patient với cột id là cột chỉ số (index_col)
# 2. Đặt lại tên các cột dữ liệu trong Dataframe:
#     * Feature_1 --> Age
#     * Feature_2 --> Gender
#     * Feature_3 --> Type
#     * Feature_4 --> Blood_pressure
#     * Feature_5 --> Cholesterol
#     * Feature_6 --> Heartbeat
#     * Feature_7 --> Thalassemia
#     * Feature_8 --> Result

# %%
#{VIẾT CODE Ở ĐÂY}
path='D:/hoctap/datatrainningpython/Data_Patient.csv'
pd_path_csv=pd.read_csv(path,index_col='id')
pd_path_csv.rename(columns={'feature_1':'Age',
                            'feature_2':'Gender',
                            'feature_3':'Type',
                            'feature_4':'Blood_pressure',
                            'feature_5':'Cholesterol',
                            'feature_6':'Heartbeat',
                            'feature_7':'Thalassemia',
                            'feature_8':'Result'}, inplace=True)
pd_path_csv
# Out:
#              Age  Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_01    63    Male    Typical angina             145          233
# Patient_02    67    Male      Asymptomatic             160          286
# Patient_03    67    Male      Asymptomatic             120          229
# Patient_04    37    Male  Non-anginal pain             130          250
# Patient_05    41  Female   Atypical angina             130          204
# ...          ...     ...               ...             ...          ...
# Patient_296   59    Male      Asymptomatic             164          176
# Patient_297   57  Female      Asymptomatic             140          241
# Patient_298   45    Male    Typical angina             110          264
# Patient_299   68    Male      Asymptomatic             144          193
# Patient_300   57    Male      Asymptomatic             130          131
#
#              Heartbeat  Thalassemia  Result
# id
# Patient_01         150          6.0       0
# Patient_02         108          3.0       1
# Patient_03         129          7.0       1
# Patient_04         187          3.0       0
# Patient_05         172          NaN       0
# ...                ...          ...     ...
# Patient_296         90          6.0       1
# Patient_297        123          7.0       1
# Patient_298        132          7.0       1
# Patient_299        141          7.0       1
# Patient_300        115          7.0       1
#
# [300 rows x 8 columns]

# %% [markdown]
# **Yêu cầu 2.2:**
# Lọc dữ liệu trong df_patient thành các DataFrame:
#     * df_male: chứa danh sách bệnh nhân Nam
#     * df_female: chứa danh sách bệnh nhân nữ
#     * df_no: danh sách những người không bị bệnh đau tim
#     * df_yes: danh sách những người bị bệnh đau tim

# %%
#{VIẾT CODE Ở ĐÂY}
df_male=pd_path_csv[pd_path_csv.Gender=='Male']
df_male
# Out:
#              Age Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_01    63   Male    Typical angina             145          233
# Patient_02    67   Male      Asymptomatic             160          286
# Patient_03    67   Male      Asymptomatic             120          229
# Patient_04    37   Male  Non-anginal pain             130          250
# Patient_06    56   Male   Atypical angina             120          236
# ...          ...    ...               ...             ...          ...
# Patient_295   41   Male   Atypical angina             120          157
# Patient_296   59   Male      Asymptomatic             164          176
# Patient_298   45   Male    Typical angina             110          264
# Patient_299   68   Male      Asymptomatic             144          193
# Patient_300   57   Male      Asymptomatic             130          131
#
#              Heartbeat  Thalassemia  Result
# id
# Patient_01         150          6.0       0
# Patient_02         108          3.0       1
# Patient_03         129          7.0       1
# Patient_04         187          3.0       0
# Patient_06         178          3.0       0
# ...                ...          ...     ...
# Patient_295        182          3.0       0
# Patient_296         90          6.0       1
# Patient_298        132          7.0       1
# Patient_299        141          7.0       1
# Patient_300        115          7.0       1
#
# [205 rows x 8 columns]

# %%
pd_path_csv
# Out:
#              Age  Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_01    63    Male    Typical angina             145          233
# Patient_02    67    Male      Asymptomatic             160          286
# Patient_03    67    Male      Asymptomatic             120          229
# Patient_04    37    Male  Non-anginal pain             130          250
# Patient_05    41  Female   Atypical angina             130          204
# ...          ...     ...               ...             ...          ...
# Patient_296   59    Male      Asymptomatic             164          176
# Patient_297   57  Female      Asymptomatic             140          241
# Patient_298   45    Male    Typical angina             110          264
# Patient_299   68    Male      Asymptomatic             144          193
# Patient_300   57    Male      Asymptomatic             130          131
#
#              Heartbeat  Thalassemia  Result
# id
# Patient_01         150          6.0       0
# Patient_02         108          3.0       1
# Patient_03         129          7.0       1
# Patient_04         187          3.0       0
# Patient_05         172          NaN       0
# ...                ...          ...     ...
# Patient_296         90          6.0       1
# Patient_297        123          7.0       1
# Patient_298        132          7.0       1
# Patient_299        141          7.0       1
# Patient_300        115          7.0       1
#
# [300 rows x 8 columns]

# %%
df_female=pd_path_csv[pd_path_csv.Gender=='Female']
df_female
# Out:
#              Age  Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_05    41  Female   Atypical angina             130          204
# Patient_07    62  Female      Asymptomatic             140          268
# Patient_08    57  Female      Asymptomatic             120          354
# Patient_12    56  Female   Atypical angina             140          294
# Patient_19    48  Female  Non-anginal pain             130          275
# ...          ...     ...               ...             ...          ...
# Patient_282   55  Female      Asymptomatic             128          205
# Patient_286   58  Female      Asymptomatic             170          225
# Patient_291   55  Female   Atypical angina             132          342
# Patient_294   63  Female      Asymptomatic             124          197
# Patient_297   57  Female      Asymptomatic             140          241
#
#              Heartbeat  Thalassemia  Result
# id
# Patient_05         172          NaN       0
# Patient_07         160          3.0       1
# Patient_08         163          3.0       0
# Patient_12         153          3.0       0
# Patient_19         139          3.0       0
# ...                ...          ...     ...
# Patient_282        130          7.0       1
# Patient_286        146          6.0       1
# Patient_291        166          3.0       0
# Patient_294        136          NaN       1
# Patient_297        123          7.0       1
#
# [95 rows x 8 columns]

# %% [markdown]
# **Yêu cầu 2.3:**
# Lọc trong df_patient dưa ra danh sách bệnh nhân thỏa mãn yêu cầu sau:
# 1. Những người bị mắc bệnh đau tim và trên 70 tuổi
# 2. Người có giới tính Female, có huyết áp trên 170 mmhg nhưng không bị bệnh đau tim.
# 3. Những người có triệu chứng đau ngực là Typical angina, giới tính Male và bị bệnh đau tim.

# %%
#{VIẾT CODE Ở ĐÂY}

df_patient=pd_path_csv[(pd_path_csv.Age>70)&(pd_path_csv.Result==0)&(pd_path_csv.Gender=='Female')]
df_patient
# Out:
#              Age  Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_43    71  Female   Atypical angina             160          302
# Patient_103   71  Female  Non-anginal pain             110          265
# Patient_233   74  Female   Atypical angina             120          269
# Patient_257   76  Female  Non-anginal pain             140          197
# Patient_273   71  Female      Asymptomatic             112          149
#
#              Heartbeat  Thalassemia  Result
# id
# Patient_43         162          3.0       0
# Patient_103        130          3.0       0
# Patient_233        121          3.0       0
# Patient_257        116          3.0       0
# Patient_273        125          3.0       0

# %%
df_patient=pd_path_csv[(pd_path_csv.Blood_pressure>170)&(pd_path_csv.Result==0)]
df_patient
# Out:
#              Age  Gender              Type  Blood_pressure  Cholesterol  \
# id
# Patient_15    52    Male  Non-anginal pain             172          199
# Patient_183   59    Male    Typical angina             178          270
# Patient_201   64  Female      Asymptomatic             180          325
#
#              Heartbeat  Thalassemia  Result
# id
# Patient_15         162          7.0       0
# Patient_183        145          7.0       0
# Patient_201        154          3.0       0

# %%
df_patient=pd_path_csv[(pd_path_csv.Type=='Typical angina')&(pd_path_csv.Gender=='Male')&(pd_path_csv.Result==0)]
df_patient
# Out:
#              Age Gender            Type  Blood_pressure  Cholesterol  \
# id
# Patient_01    63   Male  Typical angina             145          233
# Patient_21    64   Male  Typical angina             110          211
# Patient_42    40   Male  Typical angina             140          199
# Patient_60    51   Male  Typical angina             125          213
# Patient_101   34   Male  Typical angina             118          182
# Patient_112   52   Male  Typical angina             118          186
# Patient_150   52   Male  Typical angina             152          298
# Patient_182   42   Male  Typical angina             148          244
# Patient_183   59   Male  Typical angina             178          270
# Patient_196   69   Male  Typical angina             160          234
# Patient_215   56   Male  Typical angina             120          193
# Patient_275   64   Male  Typical angina             170          227
#
#              Heartbeat  Thalassemia  Result
# id
# Patient_01         150          6.0       0
# Patient_21         144          NaN       0
# Patient_42         178          7.0       0
# Patient_60         125          3.0       0
# Patient_101        174          3.0       0
# Patient_112        190          6.0       0
# Patient_150        178          7.0       0
# Patient_182        178          3.0       0
# Patient_183        145          7.0       0
# Patient_196        131          3.0       0
# Patient_215        162          7.0       0
# Patient_275        155          7.0       0

# %% [markdown]
# **Yêu cầu 2.4:** Xác định:
# 1. Chỉ số huyết áp (Blood_pressure) thấp nhất, cao nhất, trung bình, trung vị và độ lệch chuẩn của tập dữ liệu
# 2. Chỉ số nhịp tim (Heartbeat) thấp nhất, cao nhất, trung bình, trung vị và độ lệch chuẩn của tập dữ liệu

# %%
#{VIẾT CODE Ở ĐÂY}

print('chi so huyet ap thap nhat',pd_path_csv['Blood_pressure'].min())
print('chi so huyet ap cao nhat',pd_path_csv['Blood_pressure'].max())
print('do lech chuan',pd_path_csv['Blood_pressure'].std())
# Out:
# chi so huyet ap thap nhat 94
# chi so huyet ap cao nhat 200
# do lech chuan 17.682497692285477

# %%
print('chi so huyet ap thap nhat',pd_path_csv['Heartbeat'].min())
print('chi so huyet ap cao nhat',pd_path_csv['Heartbeat'].max())
print('do lech chuan',pd_path_csv['Heartbeat'].std())
# Out:
# chi so huyet ap thap nhat 71
# chi so huyet ap cao nhat 202
# do lech chuan 22.818595118151098

# %% [markdown]
# **Yêu cầu 2.5: Xác định:**
# 1. Số giá trị khác nhau của thuộc tính Type
# 2. Vẽ đồ thị dạng cột thể hiện kết quả thống kê số lượng theo từng giá trị khác nhau của thuộc tính Type

# %%
#{VIẾT CODE Ở ĐÂY}
import matplotlib.pyplot as plt
import pandas as pd
pd_path_csv['Type'].unique()
unique_type = pd_path_csv['Type'].value_counts()
unique_type
# Out:
# Asymptomatic        139
# Non-anginal pain     84
# Atypical angina      49
# Typical angina       23
# Name: Type, dtype: int64

# %%
plt.bar(unique_type.index,unique_type.values)
# Out:
# <BarContainer object of 4 artists>

# %%
#{VIẾT CODE Ở ĐÂY}

# %% [markdown]
# # THỰC HÀNH 3:

# %% [markdown]
# BVN
